# %%
import pandas as pd
import numpy as np
import gensim
from gensim.utils import tokenize
from gensim.parsing.preprocessing import remove_stopwords
from gensim.corpora import Dictionary
from gensim.models.ldamodel import LdaModel
from nltk.stem.snowball import SnowballStemmer

# %% [markdown]
# # Model

# %%
trained_model=LdaModel.load('../gensim_data/trained_model.tmp')
dictionary=Dictionary.load('../gensim_data/Dictionary.tmp')
X=pd.read_csv('..\..\..\..\Local Data\project_5_data\\aylien\\aylien_body_processed.csv')

# %%
X
# Out:
#        Unnamed: 0                                               body  \
# 0               0  Dharwad: With water sources getting dry, Dharw...
# 1               1  Hawaii is marking the first anniversary of one...
# 2               2  LEILANI ESTATES, Hawaii — A year after a volca...
# 3               3  MOSCOW (UrduPoint News / Sputnik - 25th May, 2...
# 4               4  Cyclone Fani has devastated the state of Odish...
# ...           ...                                                ...
# 34220       34220  Parts of Darwin's central business district ha...
# 34221       34221  Severe thunderstorms have dumped hail and wind...
# 34222       34222  With dams and creeks bone dry in drought-stric...
# 34223       34223  Roofs have been torn off buildings and thrown ...
# 34224       34224  The water security crisis in regional Australi...
#
#                                                processed  \
# 0      ['dharwad', 'with', 'water', 'sources', 'getti...
# 1      ['hawaii', 'marking', 'anniversary', 'largest'...
# 2      ['leilani', 'estates', 'hawaii', 'a', 'year', ...
# 3      ['moscow', 'urdupoint', 'news', 'sputnik', 'th...
# 4      ['cyclone', 'fani', 'devastated', 'state', 'od...
# ...                                                  ...
# 34220  ['parts', 'darwin', 's', 'central', 'business'...
# 34221  ['severe', 'thunderstorms', 'dumped', 'hail', ...
# 34222  ['with', 'dams', 'creeks', 'bone', 'dry', 'dro...
# 34223  ['roofs', 'torn', 'buildings', 'thrown', 'half...
# 34224  ['the', 'water', 'security', 'crisis', 'region...
#
#                                                  stemmed
# 0      ['dharwad', 'with', 'water', 'sourc', 'get', '...
# 1      ['hawaii', 'mark', 'anniversari', 'largest', '...
# 2      ['leilani', 'estat', 'hawaii', 'a', 'year', 'v...
# 3      ['moscow', 'urdupoint', 'news', 'sputnik', 'th...
# 4      ['cyclon', 'fani', 'devast', 'state', 'odisha'...
# ...                                                  ...
# 34220  ['part', 'darwin', 's', 'central', 'busi', 'di...
# 34221  ['sever', 'thunderstorm', 'dump', 'hail', 'win...
# 34222  ['with', 'dam', 'creek', 'bone', 'dri', 'droug...
# 34223  ['roof', 'torn', 'build', 'thrown', 'half', 'k...
# 34224  ['the', 'water', 'secur', 'crisi', 'region', '...
#
# [34225 rows x 4 columns]

# %%
snow=SnowballStemmer("english")

# %%
#given a probability prediction from the LDA model of form
#[(topic1, prob1), (topic2, prob2),...]  
#returns the topic number with the the highest assigned probabiltiy.

def probs_to_topic(probs):
    assigned_topic=-1
    max_prob=0
    for topic, prob in probs:
        if prob > max_prob:
            assigned_topic=topic
            max_prob=prob
    return assigned_topic

# %% [markdown]
# **Topic Index Reference**
# (These are not exact rules, and are topics classified by the unsupervised trained LDA model)
#
# 0: Global Warming/Drought/Climate disasters.
#
# 1: Fires
#
# 2: Earthquakes/Volcanos/Seismic Events
#
# 3: Urban/Other (This is a weird one -- I think here were lots of airline accidents in the training data, and any article that talks about the urban ramifications of a disaster tends to get sorted here.).
#
# 4: Storms/Hurricanes
#
# 5: Floods/Rains

# %%
trained_model.print_topics()
# Out:
# [(0,
#   '0.020*"water" + 0.013*"year" + 0.009*"climat" + 0.007*"chang" + 0.006*"it" + 0.006*"drought" + 0.006*"govern" + 0.005*"flood" + 0.005*"citi" + 0.005*"level"'),
#  (1,
#   '0.027*"fire" + 0.011*"burn" + 0.010*"firefight" + 0.009*"australia" + 0.009*"bushfir" + 0.008*"south" + 0.008*"home" + 0.008*"state" + 0.008*"condit" + 0.007*"temperatur"'),
#  (2,
#   '0.029*"earthquak" + 0.017*"magnitud" + 0.015*"quak" + 0.013*"report" + 0.012*"a" + 0.011*"mile" + 0.011*"damag" + 0.010*"erupt" + 0.009*"island" + 0.008*"hit"'),
#  (3,
#   '0.013*"i" + 0.007*"it" + 0.007*"island" + 0.006*"we" + 0.006*"home" + 0.006*"t" + 0.005*"famili" + 0.005*"polic" + 0.005*"a" + 0.005*"hous"'),
#  (4,
#   '0.024*"storm" + 0.022*"flood" + 0.017*"hurrican" + 0.016*"rain" + 0.012*"weather" + 0.012*"wind" + 0.011*"warn" + 0.010*"dorian" + 0.007*"south" + 0.007*"expect"'),
#  (5,
#   '0.021*"flood" + 0.014*"district" + 0.013*"rain" + 0.011*"state" + 0.011*"water" + 0.009*"heavi" + 0.008*"india" + 0.007*"offici" + 0.007*"affect" + 0.006*"river"')]

# %% [markdown]
# ## Preprocessing/Prediction

# %%
#input : for lack of a better assumption, let's assume that the input will be a dataframe that has one article per row,
#        and a feature named "body" of it's unprocessed body text as a string.
#        this could include title text as well, but didn't want to put too many assumptions on the input

#output: the same dataframe with three columns appended: token list, corpus (where the corpus is the token ids), 
##and predicted category

def body_topic(dataframe):
    text_body=dataframe['body'].values
    text_body=[remove_stopwords(body) for body in text_body]
    text_body=[tokenize(body, deacc="True", lowercase="True") for body in text_body]
    text_body=[[snow.stem(token) for token in word_list] for word_list in text_body]
    body_df=dataframe[['body']]
    dataframe['tokens']=[list(gen) for gen in text_body]
    dataframe['corpus']=[dictionary.doc2bow(doc) for doc in dataframe['tokens']]
    dataframe['predicted_topic']= [probs_to_topic(topic_probs)for topic_probs in trained_model.get_document_topics(dataframe['corpus'])]
    return dataframe

# %%
X
# Out:
#        Unnamed: 0                                               body  \
# 0               0  Dharwad: With water sources getting dry, Dharw...
# 1               1  Hawaii is marking the first anniversary of one...
# 2               2  LEILANI ESTATES, Hawaii — A year after a volca...
# 3               3  MOSCOW (UrduPoint News / Sputnik - 25th May, 2...
# 4               4  Cyclone Fani has devastated the state of Odish...
# ...           ...                                                ...
# 34220       34220  Parts of Darwin's central business district ha...
# 34221       34221  Severe thunderstorms have dumped hail and wind...
# 34222       34222  With dams and creeks bone dry in drought-stric...
# 34223       34223  Roofs have been torn off buildings and thrown ...
# 34224       34224  The water security crisis in regional Australi...
#
#                                                processed  \
# 0      ['dharwad', 'with', 'water', 'sources', 'getti...
# 1      ['hawaii', 'marking', 'anniversary', 'largest'...
# 2      ['leilani', 'estates', 'hawaii', 'a', 'year', ...
# 3      ['moscow', 'urdupoint', 'news', 'sputnik', 'th...
# 4      ['cyclone', 'fani', 'devastated', 'state', 'od...
# ...                                                  ...
# 34220  ['parts', 'darwin', 's', 'central', 'business'...
# 34221  ['severe', 'thunderstorms', 'dumped', 'hail', ...
# 34222  ['with', 'dams', 'creeks', 'bone', 'dry', 'dro...
# 34223  ['roofs', 'torn', 'buildings', 'thrown', 'half...
# 34224  ['the', 'water', 'security', 'crisis', 'region...
#
#                                                  stemmed
# 0      ['dharwad', 'with', 'water', 'sourc', 'get', '...
# 1      ['hawaii', 'mark', 'anniversari', 'largest', '...
# 2      ['leilani', 'estat', 'hawaii', 'a', 'year', 'v...
# 3      ['moscow', 'urdupoint', 'news', 'sputnik', 'th...
# 4      ['cyclon', 'fani', 'devast', 'state', 'odisha'...
# ...                                                  ...
# 34220  ['part', 'darwin', 's', 'central', 'busi', 'di...
# 34221  ['sever', 'thunderstorm', 'dump', 'hail', 'win...
# 34222  ['with', 'dam', 'creek', 'bone', 'dri', 'droug...
# 34223  ['roof', 'torn', 'build', 'thrown', 'half', 'k...
# 34224  ['the', 'water', 'secur', 'crisi', 'region', '...
#
# [34225 rows x 4 columns]

# %%
process_body(X.head(50))
# Out:
# <ipython-input-7-4bbd91ab5239>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['tokens']=[list(gen) for gen in text_body]
# <ipython-input-7-4bbd91ab5239>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['corpus']=[dictionary.doc2bow(doc) for doc in dataframe['tokens']]
# <ipython-input-7-4bbd91ab5239>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['predicted_topic']= [probs_to_topic(topic_probs)for topic_probs in trained_model.get_document_topics(dataframe['corpus'])]
#     Unnamed: 0                                               body  \
# 0            0  Dharwad: With water sources getting dry, Dharw...
# 1            1  Hawaii is marking the first anniversary of one...
# 2            2  LEILANI ESTATES, Hawaii — A year after a volca...
# 3            3  MOSCOW (UrduPoint News / Sputnik - 25th May, 2...
# 4            4  Cyclone Fani has devastated the state of Odish...
# 5            5  Image caption\n                \n             ...
# 6            6  The acute water crisis raging across the state...
# 7            7  Make sense of the  2019 Lok Sabha elections  a...
# 8            8  CHENNAI, India, May 20 (Thomson Reuters Founda...
# 9            9  A hurricane is a large rotating storm that for...
# 10          10  However, real estate agents and mortgage lende...
# 11          11  A spate of tornadoes raked across the Southern...
# 12          12  The Latest on severe weather in the Southern P...
# 13          13  Tornado in Oklahoma, Friday kicks off a multi-...
# 14          14  The central US is being bombarded by severe st...
# 15          15  (CNN) If you're in the central US, you can wav...
# 16          16  The frequency of heat waves and their duration...
# 17          17  For many across the country it was a dreary an...
# 18          18  Rain and thundershower, triggered by a western...
# 19          19  PUNE: The frequency of heat waves and their du...
# 20          20  Heavy rainfall and violent thunder will swoop ...
# 21          21  The India Meteorological Department (IMD) has ...
# 22          22  MANILA, May 17 (Thomson Reuters Foundation) - ...
# 23          23  Gregory Jaczko served on the Nuclear Regulator...
# 24          24  The water level of the Kashyapi dam in Nashik ...
# 25          25  Indian residents ride a bike along a road afte...
# 26          26  An elderly couple have seen the cost of their ...
# 27          27  An unusually wet spring storm that began sprin...
# 28          28  MELBOURNE, Fla. – Having your name associated ...
# 29          29  Share This Story!\nLet friends in your social ...
# 30          30  'Water is what's killing people': Hurricanes c...
# 31          31  CLOSE\n\n\n\n\n\n    The view outside an HH-60...
# 32          32  Authored by Michael Snyder via The Economic Co...
# 33          33  Severe thunderstorms and even tornadoes will t...
# 34          34  The US government isn’t ready to deal with the...
# 35          35  4,000 Spotted Deer Missing From Balukhand-Kona...
# 36          36  AS many as 200 villages in Pune district are f...
# 37          37  Glacier Point Road, the pathway to one of the ...
# 38          38  Radio stations in Florida plan to run twice-an...
# 39          39  7-day precipitation forecast from the National...
# 40          40  Boeing told played down concerns of a second 7...
# 41          41  As the concentration of pollutants in the capi...
# 42          42  President Donald Trump has repeatedly claimed ...
# 43          43  (Bloomberg) -- As a drought ravages crops in A...
# 44          44  Bhubaneswar: Cyclone Fani , which hit the stat...
# 45          45  Homeless encampments along the Sacramento rive...
# 46          46  The Jammu-Srinagar national highway was closed...
# 47          47  President Donald Trump has repeatedly claimed ...
# 48          48  Raw video: Homeless campers in Sacramento, Cal...
# 49          49  Make sense of the  2019 Lok Sabha elections  a...
#
#                                             processed  \
# 0   ['dharwad', 'with', 'water', 'sources', 'getti...
# 1   ['hawaii', 'marking', 'anniversary', 'largest'...
# 2   ['leilani', 'estates', 'hawaii', 'a', 'year', ...
# 3   ['moscow', 'urdupoint', 'news', 'sputnik', 'th...
# 4   ['cyclone', 'fani', 'devastated', 'state', 'od...
# 5   ['image', 'caption', 'thousands', 'saplings', ...
# 6   ['the', 'acute', 'water', 'crisis', 'raging', ...
# 7   ['make', 'sense', 'lok', 'sabha', 'elections',...
# 8   ['chennai', 'india', 'may', 'thomson', 'reuter...
# 9   ['a', 'hurricane', 'large', 'rotating', 'storm...
# 10  ['however', 'real', 'estate', 'agents', 'mortg...
# 11  ['a', 'spate', 'tornadoes', 'raked', 'southern...
# 12  ['the', 'latest', 'severe', 'weather', 'southe...
# 13  ['tornado', 'oklahoma', 'friday', 'kicks', 'mu...
# 14  ['the', 'central', 'us', 'bombarded', 'severe'...
# 15  ['cnn', 'if', 'you', 're', 'central', 'us', 'w...
# 16  ['the', 'frequency', 'heat', 'waves', 'duratio...
# 17  ['for', 'country', 'dreary', 'grey', 'day', 'y...
# 18  ['rain', 'thundershower', 'triggered', 'wester...
# 19  ['pune', 'the', 'frequency', 'heat', 'waves', ...
# 20  ['heavy', 'rainfall', 'violent', 'thunder', 's...
# 21  ['the', 'india', 'meteorological', 'department...
# 22  ['manila', 'may', 'thomson', 'reuters', 'found...
# 23  ['gregory', 'jaczko', 'served', 'nuclear', 're...
# 24  ['the', 'water', 'level', 'kashyapi', 'dam', '...
# 25  ['indian', 'residents', 'ride', 'bike', 'road'...
# 26  ['an', 'elderly', 'couple', 'seen', 'cost', 'h...
# 27  ['an', 'unusually', 'wet', 'spring', 'storm', ...
# 28  ['melbourne', 'fla', 'having', 'associated', '...
# 29  ['share', 'this', 'story', 'let', 'friends', '...
# 30  ['water', 'what', 's', 'killing', 'people', 'h...
# 31  ['close', 'the', 'view', 'outside', 'hh', 'g',...
# 32  ['authored', 'michael', 'snyder', 'the', 'econ...
# 33  ['severe', 'thunderstorms', 'tornadoes', 'thre...
# 34  ['the', 'us', 'government', 'isn', 't', 'ready...
# 35  ['spotted', 'deer', 'missing', 'from', 'balukh...
# 36  ['as', 'villages', 'pune', 'district', 'facing...
# 37  ['glacier', 'point', 'road', 'pathway', 'treas...
# 38  ['radio', 'stations', 'florida', 'plan', 'run'...
# 39  ['day', 'precipitation', 'forecast', 'national...
# 40  ['boeing', 'told', 'played', 'concerns', 'seco...
# 41  ['as', 'concentration', 'pollutants', 'capital...
# 42  ['president', 'donald', 'trump', 'repeatedly',...
# 43  ['bloomberg', 'as', 'drought', 'ravages', 'cro...
# 44  ['bhubaneswar', 'cyclone', 'fani', 'hit', 'sta...
# 45  ['homeless', 'encampments', 'sacramento', 'riv...
# 46  ['the', 'jammu', 'srinagar', 'national', 'high...
# 47  ['president', 'donald', 'trump', 'repeatedly',...
# 48  ['raw', 'video', 'homeless', 'campers', 'sacra...
# 49  ['make', 'sense', 'lok', 'sabha', 'elections',...
#
#                                               stemmed  \
# 0   ['dharwad', 'with', 'water', 'sourc', 'get', '...
# 1   ['hawaii', 'mark', 'anniversari', 'largest', '...
# 2   ['leilani', 'estat', 'hawaii', 'a', 'year', 'v...
# 3   ['moscow', 'urdupoint', 'news', 'sputnik', 'th...
# 4   ['cyclon', 'fani', 'devast', 'state', 'odisha'...
# 5   ['imag', 'caption', 'thousand', 'sapl', 'plant...
# 6   ['the', 'acut', 'water', 'crisi', 'rage', 'sta...
# 7   ['make', 'sens', 'lok', 'sabha', 'elect', 'res...
# 8   ['chennai', 'india', 'may', 'thomson', 'reuter...
# 9   ['a', 'hurrican', 'larg', 'rotat', 'storm', 'f...
# 10  ['howev', 'real', 'estat', 'agent', 'mortgag',...
# 11  ['a', 'spate', 'tornado', 'rake', 'southern', ...
# 12  ['the', 'latest', 'sever', 'weather', 'souther...
# 13  ['tornado', 'oklahoma', 'friday', 'kick', 'mul...
# 14  ['the', 'central', 'us', 'bombard', 'sever', '...
# 15  ['cnn', 'if', 'you', 're', 'central', 'us', 'w...
# 16  ['the', 'frequenc', 'heat', 'wave', 'durat', '...
# 17  ['for', 'countri', 'dreari', 'grey', 'day', 'y...
# 18  ['rain', 'thundershow', 'trigger', 'western', ...
# 19  ['pune', 'the', 'frequenc', 'heat', 'wave', 'd...
# 20  ['heavi', 'rainfal', 'violent', 'thunder', 'sw...
# 21  ['the', 'india', 'meteorolog', 'depart', 'imd'...
# 22  ['manila', 'may', 'thomson', 'reuter', 'founda...
# 23  ['gregori', 'jaczko', 'serv', 'nuclear', 'regu...
# 24  ['the', 'water', 'level', 'kashyapi', 'dam', '...
# 25  ['indian', 'resid', 'ride', 'bike', 'road', 'c...
# 26  ['an', 'elder', 'coupl', 'seen', 'cost', 'home...
# 27  ['an', 'unusu', 'wet', 'spring', 'storm', 'beg...
# 28  ['melbourn', 'fla', 'have', 'associ', 'tropic'...
# 29  ['share', 'this', 'stori', 'let', 'friend', 's...
# 30  ['water', 'what', 's', 'kill', 'peopl', 'hurri...
# 31  ['close', 'the', 'view', 'outsid', 'hh', 'g', ...
# 32  ['author', 'michael', 'snyder', 'the', 'econom...
# 33  ['sever', 'thunderstorm', 'tornado', 'threaten...
# 34  ['the', 'us', 'govern', 'isn', 't', 'readi', '...
# 35  ['spot', 'deer', 'miss', 'from', 'balukhand', ...
# 36  ['as', 'villag', 'pune', 'district', 'face', '...
# 37  ['glacier', 'point', 'road', 'pathway', 'treas...
# 38  ['radio', 'station', 'florida', 'plan', 'run',...
# 39  ['day', 'precipit', 'forecast', 'nation', 'wea...
# 40  ['boe', 'told', 'play', 'concern', 'second', '...
# 41  ['as', 'concentr', 'pollut', 'capit', 'dip', '...
# 42  ['presid', 'donald', 'trump', 'repeat', 'claim...
# 43  ['bloomberg', 'as', 'drought', 'ravag', 'crop'...
# 44  ['bhubaneswar', 'cyclon', 'fani', 'hit', 'stat...
# 45  ['homeless', 'encamp', 'sacramento', 'river', ...
# 46  ['the', 'jammu', 'srinagar', 'nation', 'highwa...
# 47  ['presid', 'donald', 'trump', 'repeat', 'claim...
# 48  ['raw', 'video', 'homeless', 'camper', 'sacram...
# 49  ['make', 'sens', 'lok', 'sabha', 'elect', 'res...
#
#                                                tokens  \
# 0   [dharwad, with, water, sourc, get, dri, dharwa...
# 1   [hawaii, mark, anniversari, largest, destruct,...
# 2   [leilani, estat, hawaii, a, year, volcano, haw...
# 3   [moscow, urdupoint, news, sputnik, th, may, th...
# 4   [cyclon, fani, devast, state, odisha, damag, n...
# 5   [imag, caption, thousand, sapl, plant, hs, die...
# 6   [the, acut, water, crisi, rage, state, summer,...
# 7   [make, sens, lok, sabha, elect, result, may, t...
# 8   [chennai, india, may, thomson, reuter, foundat...
# 9   [a, hurrican, larg, rotat, storm, form, tropic...
# 10  [howev, real, estat, agent, mortgag, lender, d...
# 11  [a, spate, tornado, rake, southern, plain, sat...
# 12  [the, latest, sever, weather, southern, plain,...
# 13  [tornado, oklahoma, friday, kick, multi, day, ...
# 14  [the, central, us, bombard, sever, storm, prod...
# 15  [cnn, if, you, re, central, us, wave, goodby, ...
# 16  [the, frequenc, heat, wave, durat, india, begi...
# 17  [for, countri, dreari, grey, day, yesterday, m...
# 18  [rain, thundershow, trigger, western, disturb,...
# 19  [pune, the, frequenc, heat, wave, durat, india...
# 20  [heavi, rainfal, violent, thunder, swoop, nort...
# 21  [the, india, meteorolog, depart, imd, predict,...
# 22  [manila, may, thomson, reuter, foundat, on, bl...
# 23  [gregori, jaczko, serv, nuclear, regulatori, c...
# 24  [the, water, level, kashyapi, dam, nashik, dis...
# 25  [indian, resid, ride, bike, road, cyclon, fani...
# 26  [an, elder, coupl, seen, cost, home, content, ...
# 27  [an, unusu, wet, spring, storm, began, sprinkl...
# 28  [melbourn, fla, have, associ, tropic, storm, c...
# 29  [share, this, stori, let, friend, social, netw...
# 30  [water, what, s, kill, peopl, hurrican, caus, ...
# 31  [close, the, view, outsid, hh, g, pave, hawk, ...
# 32  [author, michael, snyder, the, econom, collaps...
# 33  [sever, thunderstorm, tornado, threaten, milli...
# 34  [the, us, govern, isn, t, readi, deal, effect,...
# 35  [spot, deer, miss, from, balukhand, konark, sa...
# 36  [as, villag, pune, district, face, water, scar...
# 37  [glacier, point, road, pathway, treasur, view,...
# 38  [radio, station, florida, plan, run, twice, an...
# 39  [day, precipit, forecast, nation, weather, ser...
# 40  [boe, told, play, concern, second, max, crash,...
# 41  [as, concentr, pollut, capit, dip, monday, s, ...
# 42  [presid, donald, trump, repeat, claim, adminis...
# 43  [bloomberg, as, drought, ravag, crop, australi...
# 44  [bhubaneswar, cyclon, fani, hit, state, may, w...
# 45  [homeless, encamp, sacramento, river, damag, f...
# 46  [the, jammu, srinagar, nation, highway, close,...
# 47  [presid, donald, trump, repeat, claim, adminis...
# 48  [raw, video, homeless, camper, sacramento, cal...
# 49  [make, sens, lok, sabha, elect, result, may, t...
#
#                                                corpus  predicted_topic
# 0   [(0, 1), (1, 1), (2, 1), (3, 1), (4, 1), (5, 1...                0
# 1   [(25, 1), (46, 3), (50, 1), (54, 2), (56, 1), ...                3
# 2   [(19, 4), (37, 1), (41, 2), (44, 3), (46, 2), ...                3
# 3   [(40, 1), (58, 1), (72, 1), (86, 1), (91, 3), ...                5
# 4   [(1, 1), (2, 1), (6, 1), (29, 2), (55, 2), (58...                5
# 5   [(1, 1), (33, 1), (45, 3), (69, 1), (90, 2), (...                0
# 6   [(0, 1), (17, 3), (19, 1), (20, 1), (22, 1), (...                5
# 7   [(1, 1), (2, 1), (14, 2), (19, 2), (22, 1), (2...                5
# 8   [(2, 1), (8, 1), (18, 1), (19, 2), (29, 2), (3...                3
# 9   [(1, 1), (2, 2), (10, 1), (14, 1), (17, 1), (2...                0
# 10  [(5, 1), (14, 1), (23, 2), (27, 1), (37, 3), (...                0
# 11  [(14, 2), (44, 1), (46, 2), (48, 1), (62, 3), ...                4
# 12  [(22, 1), (44, 1), (62, 2), (70, 1), (84, 1), ...                4
# 13  [(13, 8), (14, 1), (19, 6), (34, 1), (35, 1), ...                4
# 14  [(1, 1), (2, 1), (6, 1), (13, 1), (14, 2), (16...                4
# 15  [(13, 4), (14, 1), (19, 4), (56, 1), (80, 1), ...                4
# 16  [(1, 2), (13, 5), (19, 7), (24, 2), (34, 1), (...                0
# 17  [(1, 1), (19, 1), (51, 1), (52, 1), (58, 1), (...                4
# 18  [(14, 1), (19, 5), (22, 2), (52, 1), (58, 1), ...                5
# 19  [(1, 2), (13, 5), (19, 7), (24, 2), (34, 1), (...                0
# 20  [(1, 1), (19, 2), (30, 1), (59, 1), (94, 5), (...                4
# 21  [(19, 2), (22, 3), (35, 1), (62, 1), (67, 1), ...                5
# 22  [(1, 2), (6, 1), (14, 7), (17, 4), (18, 1), (1...                0
# 23  [(0, 1), (4, 1), (16, 2), (17, 2), (22, 1), (2...                0
# 24  [(2, 3), (17, 1), (19, 3), (29, 8), (33, 2), (...                5
# 25  [(2, 2), (6, 1), (8, 1), (19, 1), (22, 4), (29...                0
# 26  [(5, 1), (10, 1), (23, 1), (25, 1), (28, 1), (...                0
# 27  [(19, 1), (25, 1), (27, 1), (30, 1), (33, 1), ...                4
# 28  [(19, 1), (22, 1), (72, 1), (90, 1), (95, 1), ...                4
# 29  [(19, 1), (22, 1), (72, 1), (90, 1), (95, 1), ...                4
# 30  [(14, 2), (46, 3), (67, 2), (70, 1), (72, 2), ...                4
# 31  [(14, 2), (25, 1), (46, 3), (54, 1), (56, 1), ...                4
# 32  [(17, 1), (18, 7), (19, 1), (22, 2), (27, 1), ...                0
# 33  [(2, 1), (19, 5), (30, 1), (33, 2), (80, 1), (...                4
# 34  [(1, 1), (2, 1), (14, 1), (23, 1), (25, 1), (3...                0
# 35  [(8, 2), (19, 1), (29, 2), (55, 1), (65, 3), (...                5
# 36  [(1, 2), (2, 3), (4, 1), (11, 1), (12, 1), (19...                5
# 37  [(46, 3), (58, 1), (67, 1), (98, 1), (152, 1),...                1
# 38  [(14, 20), (19, 4), (52, 1), (58, 11), (62, 1)...                4
# 39  [(13, 4), (14, 2), (19, 8), (20, 1), (34, 1), ...                4
# 40  [(2, 1), (14, 1), (16, 2), (22, 1), (43, 1), (...                3
# 41  [(14, 5), (18, 2), (19, 2), (30, 1), (40, 1), ...                0
# 42  [(2, 5), (19, 1), (51, 1), (55, 2), (59, 1), (...                0
# 43  [(16, 1), (18, 4), (22, 2), (30, 2), (33, 3), ...                0
# 44  [(13, 5), (19, 1), (22, 4), (29, 5), (34, 1), ...                5
# 45  [(1, 1), (5, 1), (14, 2), (22, 2), (29, 5), (3...                3
# 46  [(1, 2), (29, 1), (84, 2), (158, 2), (204, 5),...                5
# 47  [(2, 5), (55, 2), (59, 1), (69, 1), (91, 3), (...                0
# 48  [(14, 3), (16, 2), (22, 1), (29, 8), (52, 2), ...                3
# 49  [(1, 2), (19, 1), (29, 1), (84, 2), (146, 1), ...                5

# %%
pip freeze
# Out:
# absl-py==0.10.0
# anaconda-client==1.7.2
# anaconda-navigator==1.9.12
# argon2-cffi @ file:///C:/ci/argon2-cffi_1596828585465/work
# astunparse==1.6.3
# async-generator==1.10
# Note: you may need to restart the kernel to use updated packages.attrs @ file:///tmp/build/80754af9/attrs_1600298409949/work
# backcall==0.2.0
# backports.functools-lru-cache==1.6.1
# backports.tempfile==1.0
# WARNING: Could not generate requirement for distribution -umpy 1.18.5 (d:\applications\anaconda3\lib\site-packages): Parse error at "'-umpy==1'": Expected W:(abcd...)
# backports.weakref==1.0.post1
# beautifulsoup4 @ file:///tmp/build/80754af9/beautifulsoup4_1601924105527/work
# bleach @ file:///tmp/build/80754af9/bleach_1600439572647/work
# blis==0.4.1
# bokeh==2.2.1
# brotlipy==0.7.0
# cachetools==4.1.1
# catalogue==1.0.0
# certifi==2020.6.20
# cffi @ file:///C:/ci/cffi_1600699246375/work
# chardet==3.0.4
# click==7.1.2
# clyent==1.2.2
# colorama @ file:///tmp/build/80754af9/colorama_1603211150991/work
# conda==4.9.1
# conda-build==3.20.4
# conda-package-handling @ file:///C:/ci/conda-package-handling_1603003327818/work
# conda-verify==3.4.2
# cryptography @ file:///C:/ci/cryptography_1601046905460/work
# cupy-cuda101==8.0.0
# cycler==0.10.0
# cymem==2.0.3
# Cython==0.29.14
# decorator==4.4.2
# defusedxml==0.6.0
# entrypoints==0.3
# fastrlock==0.5
# filelock==3.0.12
# Flask==1.1.2
# fsspec @ file:///tmp/build/80754af9/fsspec_1602684995936/work
# future==0.18.2
# gast==0.3.3
# gensim==3.8.3
# glob2==0.7
# google-auth==1.22.1
# google-auth-oauthlib==0.4.1
# google-pasta==0.2.0
# grpcio==1.32.0
# h5py==2.10.0
# idna @ file:///tmp/build/80754af9/idna_1593446292537/work
# imbalanced-learn @ file:///home/conda/feedstock_root/build_artifacts/imbalanced-learn_1592145894352/work
# importlib-metadata @ file:///tmp/build/80754af9/importlib-metadata_1602276842396/work
# ipykernel @ file:///C:/ci/ipykernel_1596190155316/work/dist/ipykernel-5.3.4-py3-none-any.whl
# ipython @ file:///C:/ci/ipython_1598865816163/work
# ipython-genutils==0.2.0
# ipywidgets @ file:///tmp/build/80754af9/ipywidgets_1601490159889/work
# itsdangerous==1.1.0
# jedi @ file:///C:/ci/jedi_1598353661586/work
# Jinja2==2.11.2
# joblib @ file:///tmp/build/80754af9/joblib_1601912903842/work
# json5==0.9.5
# jsonschema @ file:///tmp/build/80754af9/jsonschema_1602607155483/work
# jupyter-client @ file:///tmp/build/80754af9/jupyter_client_1601311786391/work
# jupyter-contrib-core==0.3.3
# jupyter-contrib-nbextensions==0.5.1
# jupyter-core==4.6.3
# jupyter-highlight-selected-word==0.2.0
# jupyter-latex-envs==1.4.6
# jupyter-nbextensions-configurator==0.4.1
# jupyterlab==2.2.6
# jupyterlab-pygments @ file:///tmp/build/80754af9/jupyterlab_pygments_1601490720602/work
# jupyterlab-server @ file:///tmp/build/80754af9/jupyterlab_server_1594164409481/work
# Keras-Preprocessing==1.1.2
# kiwisolver==1.2.0
# libarchive-c==2.9
# Markdown==3.3.1
# MarkupSafe==1.1.1
# matplotlib==3.3.1
# menuinst==1.4.16
# missingno==0.4.2
# mistune==0.8.4
# mkl-fft==1.2.0
# mkl-random==1.1.1
# mkl-service==2.3.0
# murmurhash==1.0.2
# navigator-updater==0.2.1
# nbclient @ file:///tmp/build/80754af9/nbclient_1602783176460/work
# nbconvert @ file:///C:/ci/nbconvert_1601914925608/work
# nbformat @ file:///tmp/build/80754af9/nbformat_1602783287752/work
# nest-asyncio @ file:///tmp/build/80754af9/nest-asyncio_1601499549014/work
# nltk @ file:///tmp/build/80754af9/nltk_1592496090529/work
# notebook @ file:///C:/ci/notebook_1601501643625/work
# numpy==1.18.5
# oauthlib==3.1.0
# olefile==0.46
# opt-einsum==3.3.0
# packaging==20.4
# pandas @ file:///C:/ci/pandas_1602083338010/work
# pandocfilters==1.4.2
# parso==0.7.0
# patsy==0.5.1
# pickleshare==0.7.5
# Pillow @ file:///C:/ci/pillow_1602770972588/work
# pkginfo==1.6.0
# plac==1.1.3
# preshed==3.0.2
# prometheus-client==0.8.0
# prompt-toolkit @ file:///tmp/build/80754af9/prompt-toolkit_1602688806899/work
# protobuf==3.13.0
# psutil @ file:///C:/ci/psutil_1598370330503/work
# pyasn1==0.4.8
# pyasn1-modules==0.2.8
# pycosat==0.6.3
# pycparser @ file:///tmp/build/80754af9/pycparser_1594388511720/work
# Pygments @ file:///tmp/build/80754af9/pygments_1600458456400/work
# pyOpenSSL @ file:///tmp/build/80754af9/pyopenssl_1594392929924/work
# pyparsing==2.4.7
# pyrsistent @ file:///C:/ci/pyrsistent_1600141795814/work
# PySocks==1.7.1
# python-dateutil==2.8.1
# pytz==2020.1
# pywin32==227
# pywinpty==0.5.7
# PyYAML==5.3.1
# pyzmq==19.0.2
# QtPy==1.9.0
# regex @ file:///C:/ci/regex_1602770567298/work
# requests @ file:///tmp/build/80754af9/requests_1592841827918/work
# requests-oauthlib==1.3.0
# rsa==4.6
# ruamel-yaml==0.15.87
# scikit-learn @ file:///C:/ci/scikit-learn_1598377018496/work
# scipy==1.5.2
# seaborn==0.11.0
# Send2Trash==1.5.0
# sip==4.19.13
# six==1.15.0
# smart-open==3.0.0
# soupsieve==2.0.1
# spacy==2.3.2
# srsly==1.0.2
# statsmodels==0.12.0
# tensorboard==2.3.0
# tensorboard-plugin-wit==1.7.0
# tensorflow==2.3.1
# tensorflow-estimator==2.3.0
# termcolor==1.1.0
# terminado==0.9.1
# testpath==0.4.4
# textblob==0.15.3
# thinc==7.4.1
# thinc-gpu-ops==0.0.4
# threadpoolctl @ file:///tmp/tmp9twdgx9k/threadpoolctl-2.1.0-py3-none-any.whl
# tornado==6.0.4
# tqdm @ file:///tmp/build/80754af9/tqdm_1602185206534/work
# traitlets @ file:///tmp/build/80754af9/traitlets_1602787416690/work
# urllib3 @ file:///tmp/build/80754af9/urllib3_1603305693037/work
# wasabi==0.8.0
# wcwidth @ file:///tmp/build/80754af9/wcwidth_1593447189090/work
# webencodings==0.5.1
# Werkzeug==1.0.1
# widgetsnbextension==3.5.1
# win-inet-pton==1.1.0
# wincertstore==0.2
# wrapt==1.12.1
# xmltodict==0.12.0
# zipp @ file:///tmp/build/80754af9/zipp_1603306325174/work
